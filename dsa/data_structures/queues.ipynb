# %%
queue means first in, first out (FIFO) data structure

think like a line of people in queue to get in a supermarket

# %%
from collections import deque
class concertqueue:
    def __init__(self):
        self.queue=deque()

    def add(self,person):
        self.queue.append(person)

    def entry(self):
        if len(self.queue)<1:
            return "no one is in queue"
        else:
            self.queue.popleft
            return self.queue

# %%
from collections import deque

d = deque()
type(d)


"""deque (pronounced deck) stands for Double-Ended Queue.

It is a data structure from the collections module that allows you to:

Add and remove elements from both ends

Do it in O(1) time (very fast)"""
# Out:
# collections.deque
