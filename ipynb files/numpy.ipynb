# %%
import numpy as np

arr = np.array([1, 2, 3, 4, 5,6])

print(arr)

print(type(arr))
# Out:
# [1 2 3 4 5 6]
# <class 'numpy.ndarray'>

# %%
arr = arr.reshape((3,2))

# %%
arr
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6]])
