# %%
List Comprehension
List comprehension offers a shorter syntax when you want to create a new list based on the values of an existing list.

By default the sort() method

# %%
#List Method

# append()	Adds an entire object at the end of the list
# insert()	Adds an element at the specified position
# clear()	Removes all the elements from the list
# copy()	Returns a copy of the list
# count()	Returns the number of elements with the specified value
# extend()	Add the elements of a list (or any iterable), to the end of the current list
# index()	Returns the index of the first element with the specified value

# pop()	Removes the element at the specified position
# remove()	Removes the item with the specified value
# reverse()	Reverses the order of the list
# sort()	Sorts the list

# %%
l = ["banana","cherry", "Orange", "Kiwi", "cherry"]
count=l.count('cherry') #Return the number of times the value "cherry" appears in the fruits list:
index=l.index('cherry')
insert=l.insert(2,'abc')
print(f"{count},{index}")
print(l)
pop=l.pop(1)
print(l)
remove=l.remove('Kiwi')
print(l)
# Out:
# 2,1
# ['banana', 'cherry', 'abc', 'Orange', 'Kiwi', 'cherry']
# ['banana', 'abc', 'Orange', 'Kiwi', 'cherry']
# ['banana', 'abc', 'Orange', 'cherry']

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
newlist = []

for x in fruits:
  if "a" in x:
    newlist.append(x)

print(newlist)
# Out:
# ['apple', 'banana', 'mango']

# %%
# list comprehension

fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
newlist = []

[x for x in fruits if "a" in x]
# Out:
# ['apple', 'banana', 'mango']

# %%
# Sort List Alphanumerically

fruits = ["cherry", "kiwi","apple", "banana",  "mango"]
fruits.sort()
fruits
# Out:
# ['apple', 'banana', 'cherry', 'kiwi', 'mango']

# %%
# sort descending 

fruits = ["cherry", "kiwi","apple", "banana",  "mango"]
fruits.sort(reverse=True)
fruits
# Out:
# ['mango', 'kiwi', 'cherry', 'banana', 'apple']

# %%
# Customize Sort Function
# You can also customize your own function by using the keyword argument key = function.

def my_fun(n):
    return abs(50 -n)

list=[100,50,75,20,80]
list.sort(key=my_fun)
list
# Out:
# [50, 75, 20, 80, 100]

# %%
#reverse

thislist = ["banana", "Orange", "Kiwi", "cherry"]
thislist.reverse()
print(thislist)
# Out:
# ['cherry', 'Kiwi', 'Orange', 'banana']

# %%
thislist = ["apple", "banana", "cherry"]
mylist = thislist.copy()
print(mylist)
# Out:
# ['apple', 'banana', 'cherry']

# %%
#join method

list1 = ["a", "b", "c"]
list2 = [1, 2, 3]

list3 = list1 + list2
print(list3)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
list1 = ["a", "b" , "c"]
list2 = [1, 2, 3]

list1.extend(list2)
print(list1)
# Out:
# ['a', 'b', 'c', 1, 2, 3]

# %%
nums = [2,7,11,15]
target = 22
num_map={}

for i in range(len(nums)):
    num=nums[i]

    needed= target-num
    if needed in num_map:
        print([num_map[needed],i]) 
    num_map[num] = i
    print(num)
    print(num_map)
# Out:
# 2
# {2: 0}
# 7
# {2: 0, 7: 1}
# 11
# {2: 0, 7: 1, 11: 2}
# [1, 3]
# 15
# {2: 0, 7: 1, 11: 2, 15: 3}

# %%
f=[3,56,1,2]
f.sort()

# %%
f=[3,56,1,2]
f.sort()
print(f)
# Out:
# [1, 2, 3, 56]

# %%
arr = [1, 2 , 3, 4, 5]
prefix =[]
prefix.append(arr[0])
for x in range(1, len(arr)):
    prefix.append(prefix[x-1] + arr[x])
    
print(prefix)
# Out:
# [1, 3, 6, 10, 15]

# %%
from collections import defaultdict
l=["eat","tea","tan","ate","nat","bat"]

l=defaultdict(str)
l
# Out:
# defaultdict(str, {})

# %%
# [[1,2,3],[4,5,6],[7,8,9]] → [[7,4,1],[8,5,2],[9,6,3]]

a=[[1,2,3],[4,5,6],[7,8,9]]
b=[[],[],[]]

for i in a:
    for j,k in enumerate(i):
        b[j].insert(0,k)
b
# Out:
# [[7, 4, 1], [8, 5, 2], [9, 6, 3]]

# %%
a=[1,2,3,4]
for i,j in enumerate(a):
    print(i,j)
# Out:
# 0 1
# 1 2
# 2 3
# 3 4

# %%
#Find the Difference of Two Arrays

# Input: nums1 = [1,2,3], nums2 = [2,4,6]
# Output: [[1,3],[4,6]]

def findDifference(self,nums1, nums2):
    k = []
    l = []
    m = []
    for i,j in zip(nums1,nums2):
        if i not in nums2 and i not in k:
            k.append(i)
        if j not in nums1 and i not in l:
            l.append(j)

    m.append(k)
    m.append(l)
    return m
    

nums1 = [1,2,3]
nums2 = [2,4,6]

k = []
l = []
m = []
for i,j in zip(nums1,nums2):
    if i not in nums2:
        k.append(i)
    if j not in nums1:
        l.append(j)

m.append(k)
m.append(l)
m
# Out:
# [[1, 3], [4, 6]]
