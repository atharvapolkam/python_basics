# %% [markdown]
# Hyperparameter tuning: It involves systematically adjusting hyperparameters, such as learning rate and batch size, to improve model performance.
# ‍
# Model pruning: This technique removes unnecessary weights and connections from the neural network, reducing its complexity and computational cost.
# ‍
# Model quantization: Quantization involves reducing the precision of the model's weights and activations, typically from 32-bit to 16-bit or 8-bit, significantly reducing memory footprint and computational requirements.
# ‍
# Precision adjustments: Also known as mixed precision training, it involves using different precision formats for different parts of the model and optimizing resource usage without compromising accuracy.

# %%
Aspect	Custom Training	Fine-Tuning (resume=True)
🔧 Definition	Training from scratch or from a pretrained base using your dataset.	Continue training an already partially trained model (resuming from last checkpoint).
🧠 Model Weights	Starts from scratch or from yolov8n.pt, yolov8m.pt, etc.	Uses your previous best.pt or last.pt checkpoint.
📂 Use Case	When starting a new project or dataset.	When you want to continue training after interruption, or fine-tune further.
🔁 resume=True needed?	❌ No (default is False)	✅ Yes (this is what tells YOLO to load the last checkpoint).
🎯 Typical Learning Rate	Higher (lr0=0.01 is default)	Lower (e.g., lr0=1e-4) to prevent overshooting learned weights.
📈 When to use	First time training on your pizza/cash/headgear dataset.	After pruning, or when accuracy needs minor improvement.

# %%
Aspect	Custom Training	Fine-Tuning (resume=True)
🔧 Definition	Training from scratch or from a pretrained base using your dataset.	Continue training an already partially trained model (resuming from last checkpoint).
🧠 Model Weights	Starts from scratch or from yolov8n.pt, yolov8m.pt, etc.	Uses your previous best.pt or last.pt checkpoint.
📂 Use Case	When starting a new project or dataset.	When you want to continue training after interruption, or fine-tune further.
🔁 resume=True needed?	❌ No (default is False)	✅ Yes (this is what tells YOLO to load the last checkpoint).
🎯 Typical Learning Rate	Higher (lr0=0.01 is default)	Lower (e.g., lr0=1e-4) to prevent overshooting learned weights.
📈 When to use	First time training on your pizza/cash/headgear dataset.	After pruning, or when accuracy needs minor improvement.

# %%
Category                 	Accuracy↑	Inference Time↑          	Example
Model Size                 	✅          	✅	y                olov8n.pt vs yolov8x.pt
Input Size                 	✅          	✅	i                mgsz=640 vs imgsz=1280
Confidence Threshold        ⚠️           ✅	                  conf=0.25 vs conf=0.6
IoU Threshold (NMS)         ✅          	✅	                 iou=0.45
Learning Rate             ✅✅           ❌	                lr0=0.01 vs lr0=0.0005
Epochs                 	    ✅          	❌	                 epochs=100
Batch Size                 	✅          	❌                    (training only)	batch=16
Augmentations             ✅✅           ❌	                Mosaic, HSV, flip, rotation



✅ For Accuracy Boost
Focus on:

imgsz

lr0

epochs

augmentations

✅ For Speed Optimization
Focus on:

model size (n/s/m)

imgsz

conf_threshold

iou_threshold
