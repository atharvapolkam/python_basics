# %%
# Q4


Input= "hello world from python"

# first letter is capital from each word

# Output="Python From World Hello"

# %%
# Q5) Creates a dictionary where:

# each smallest odd number becomes the key

# the corresponding smallest even number becomes the value

# Pair them based on their sorted order.

data = [8, 2, 15, 1, 9, 10]

# expected_output = {
#     1:2,
#     9:8,
#     15:10

# }

# %%
#Q7 Write a Python function that merges all overlapping intervals and 
# returns a list of non-overlapping intervals covering all ranges.

# Input

intervals = [[1,3],[2,6],[8,10],[15,18]]

# Output

# [[1,6],[8,10],[15,18]]

# %%
# Q1 Write a Python program that takes a list of values and returns the sum of only valid integers.
# If a value cannot be converted to an integer, use using try-except.


data = ["10", "20", "abc", "40", "5x", "30"]

# output = 100

# %%
# Q2 Write a program to find the most frequent element in the list.

data = [4,5,6,4,3,4,5,6,6,6]

#output1 = 6

#output2 = {
#         num1 : frequency of num1,
#         num2 : frequency of num2,
#         ...
# }

# %%
#q3  Write a program that groups words based on their length.

words = ["cat", "dog", "elephant", "bat", "tiger", "lion"]

# output
# {
# 3: ['cat', 'dog', 'bat'],
# 5: ['tiger'],
# 4: ['lion'],
# 8: ['elephant']
# }

# %%
#Q4 Q3 — Find the Pair With Maximum Sum

# Find two numbers whose sum is maximum but less than a target.

# data = [8,7,2,5,3,1]
# target = 10

#explanation 
# target is 10 so max sum we can get is less than or equal to 9
# so key is sum 8 +1 becomes 9 ,and  value is list of indexes of 8 and 1 i.e. 0 and 5


#output = {9 :[0,5]}

# %%
# Q 6

# Problem: Shape Area Calculator (OOP)

# Create a program using Object-Oriented Programming that demonstrates:

# Encapsulation,Inheritance,Polymorphism

# Requirements

# Create a base class Shape.

# It should contain a private attribute name.

# Provide getter method to access the name.

# Define a method:

# area()

# This method will be overridden in subclasses.

# Create two subclasses that inherit from Shape.

# Rectangle

# Attributes:

# length, width

# Area formula:
# length * width


# Circle

# Attribute:
# radius

# Area formula:

# 3.14 * radius * radius

# Demonstrate polymorphism

# Write a loop that takes different shape objects and prints their areas using the same method call.

# Example Usage
# Rectangle area: 20
# Circle area: 78.5
