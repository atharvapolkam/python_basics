# %%
# *
# **
# ***
# ****

n = 5
for i in range(1,n):
    print("*"*i)
# Out:
# *
# **
# ***
# ****

# %%
# ****
# ***
# **
# *
n=5
for i in range(n,0,-1):
    print("*"*i)
# Out:
# *****
# ****
# ***
# **
# *

# %%
#     *
#    **
#   ***
#  ****

for i in range(1,n):
    print(" "*(n-i),"*"*i)
# Out:
#      *
#     **
#    ***
#   ****

# %%
#    *   
#   ***  
#  *****
# *******

n=3
for i in range(n):
    print(" "*(n-i-1) ,"*"*(2*i +1),)
# Out:
#    *
#   ***
#  *****
