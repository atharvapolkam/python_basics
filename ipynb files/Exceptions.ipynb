# %%
🧱 3. Most Common Built-in Exceptions (with examples)
Exception	When It Happens	Example
KeyError	Accessing a non-existent dictionary key	my_dict["missing"]
IndexError	Accessing an invalid list/tuple index	my_list[100]
ValueError	Passing a wrong value to a function	int("abc")
TypeError	Using wrong data type for an operation	3 + "hi"
NameError	Using an undefined variable	print(x) before x is defined
AttributeError	Accessing an attribute/method that doesn’t exist	"abc".append("d")
ZeroDivisionError	Division/modulus by zero	1 / 0
FileNotFoundError	File doesn’t exist	open("nofile.txt")
IOError	Generic I/O failure (reading/writing file/network)	—
OSError	OS-level error (permissions, missing path)	os.remove("nofile")
ImportError	Importing a missing module or function	import not_exist
ModuleNotFoundError	A more specific ImportError	import fake_module
RuntimeError	Generic runtime problem	raise RuntimeError("Something broke")
AssertionError	Assertion failed	assert 2 + 2 == 5
RecursionError	Too deep recursive calls	recursive_func() calling itself too many times
MemoryError	Out of memory	Trying to load a 100 GB file
TimeoutError	Operation took too long (socket, subprocess)	—
PermissionError	No permission to read/write a file	open("/root/file.txt")
StopIteration	Iterator exhausted (used internally in loops)	next(iter([]))
KeyboardInterrupt	When you press Ctrl+C	—

# %%
#how to disable pylint

# pylint: disable=global-statement
