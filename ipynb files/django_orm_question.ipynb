# %%
#Find all DeviceModel entries that belong to a site with client name 'Dominos'
DeviceModel.objects.filter(site__client='DOMINOS')

#Get a device that has the device_name equal to "NVR_Main" and belongs to a site whose region is "DPI North 1"
DeviceModel.objects.filter(site__name='adf',site__region='DPI West 1')

# %%
#Find all devices where enable_analytics=True and device_status=False.
DeviceModel.objects.filter(enable_analytics=True,device_status=False)
