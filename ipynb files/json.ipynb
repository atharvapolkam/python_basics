# %%
import json

# some JSON:
x =  '{ "name":"John", "age":30, "city":"New York"}'

# %%
type(x)
y = json.loads(x)   # to convert JSON string to Python dict
z = json.dumps(y)  # to convert Python dict to JSON string

# %%
import json

print(json.dumps({"name": "John", "age": 30}))
print(json.dumps(["apple", "bananas"]))
print(json.dumps(("apple", "bananas")))
print(json.dumps("hello"))
print(json.dumps(42))
print(json.dumps(31.76))
print(json.dumps(True))
print(json.dumps(False))
# Out:
# {"name": "John", "age": 30}
# ["apple", "bananas"]
# ["apple", "bananas"]
# "hello"
# 42
# 31.76
# true
# false
