# %%
#Q1) Convert this dictionary into a list of tuples where value comes first and key second.

data = {'a': 10, 'b': 20, 'c': 30}

#convert dict into list of tuples containing key and value
# op = [(10, 'a'), (20, 'b'), (30, 'c')]

# %%
# Q8 Write a Python program to count how many even and odd numbers are present in the list 


data = [4, 7, 10, 13, 16, 19]

# output = {
#     'even':3,
#     'odd':3
# }

# %%
# Q9 print 12.2 to 12.8 using any loop

# %%
# Q2

# You are given the output of multiple detection models stored in a dictionary.
# Each key represents a model name, and its value contains:

# detections: a list of detection dictionaries.
# Each detection has the fields:

# class

# class_id

# confidence

# bbox

# count: total number of detections from that model.

# Write a Python program that:

# Extracts detections from the model named "ganesh".

# Filters only those detections where the class is "a".

# Returns a dictionary containing:

# the filtered detections

# the updated count of those detections.

input_data = {
"ganesh": {
    "detections": [
        {'class': 'a','class_id': 0,'confidence': 0.8789905607700348,'bbox': [111, 440, 251, 639]},
        {'class': 'a','class_id': 0,'confidence': 0.88844302892684937,'bbox': [164, 74, 252, 333]},
        {'class': 'b','class_id': 1,'confidence': 0.8789905607700348,'bbox': [111, 440, 251, 639]}
    ],
    "count": 3
},
"piyusha": {
    "detections": [
        {'class': 'j','class_id': 0,'confidence': 0.8789905607700348,'bbox': [111, 440, 251, 639]},
        {'class': 'j','class_id': 1,'confidence': 0.8789905607700348,'bbox': [111, 440, 251, 639]}
    ],
    "count": 2
}
}

# output = {
#  'detections': [
#      {'class': 'a','class_id': 0,'confidence': 0.8789905607700348,'bbox': [111, 440, 251, 639]},
#      {'class': 'a','class_id': 0,'confidence': 0.8884430289268493,'bbox': [164, 74, 252, 333]}
#  ],
#  'count': 2
# }

# %%
# Q3 — Rotate Matrix 90° Clockwise

Input = [
[1,2,3],
[4,5,6],
[7,8,9]
]

# output = [
# [7,4,1],
# [8,5,2],
# [9,6,3]
# ]
